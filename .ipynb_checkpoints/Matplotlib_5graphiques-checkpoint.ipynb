# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# %%
iris = load_iris()

x = iris.data
y = iris.target
names = list(iris.target_names)

print(f'x contient {x.shape[0]} exemples et {x.shape[1]} variables')
print(f'il y a {np.unique(y).size} classes')
# Out:
# x contient 150 exemples et 4 variables
# il y a 3 classes

# %% [markdown]
# # (5) Graphique de classification avec plt.scatter

# %%
plt.scatter(x[:,0], x[:, 1], c = y, alpha = 0.5, s = x[:,2]*100) #alpha controle la transpence, s controle la taille des points
plt.xlabel('longueur sepal')
plt.ylabel('largeur sepal')
# Out:
# Text(0, 0.5, 'largeur sepal')

# %% [markdown]
# # (4) Graphique 3D

# %%
#%matplotlib
from mpl_toolkits.mplot3d import Axes3D

# %%
ax = plt.axes(projection = '3d')
ax.scatter(x[:, 0], x[:, 1], x[:, 2], c = y)

# %%
f = lambda x, y: np.sin(x) + np.cos(x + y)

# %%
X = np.linspace(0, 5, 100)
Y = np.linspace(0, 5, 100)
X,Y = np.meshgrid(X, Y)

Z = f(X, Y)
Z.shape
# Out:
# (100, 100)

# %%
ax = plt.axes(projection = '3d')
ax.plot_surface(X, Y, Z, cmap = 'plasma')

# %% [markdown]
# # (3) Histogramme

# %% [markdown]
# Permet de voir la distribution des donnees sur lesquelles on travaile

# %%
plt.hist(x[:,0], bins = 30) #bins permet de sectionner l'histogramme
# Out:
# (array([ 4.,  1.,  4.,  2.,  5., 16.,  9.,  4.,  1.,  6., 13.,  8.,  7.,
#          3.,  6., 10.,  9.,  7.,  5.,  2., 11.,  4.,  1.,  1.,  4.,  1.,
#          0.,  1.,  4.,  1.]),
#  array([4.3 , 4.42, 4.54, 4.66, 4.78, 4.9 , 5.02, 5.14, 5.26, 5.38, 5.5 ,
#         5.62, 5.74, 5.86, 5.98, 6.1 , 6.22, 6.34, 6.46, 6.58, 6.7 , 6.82,
#         6.94, 7.06, 7.18, 7.3 , 7.42, 7.54, 7.66, 7.78, 7.9 ]),
#  <BarContainer object of 30 artists>)

# %%
plt.hist(x[:,0], bins = 20)
plt.hist(x[:,1], bins = 20)
# Out:
# (array([ 1.,  3.,  4.,  3.,  8., 14., 14., 10., 26., 11., 19., 12.,  6.,
#          4.,  9.,  2.,  1.,  1.,  1.,  1.]),
#  array([2.  , 2.12, 2.24, 2.36, 2.48, 2.6 , 2.72, 2.84, 2.96, 3.08, 3.2 ,
#         3.32, 3.44, 3.56, 3.68, 3.8 , 3.92, 4.04, 4.16, 4.28, 4.4 ]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist2d(x[:,0], x[:,1], cmap = 'Blues')
plt.xlabel('longueur sepal')
plt.ylabel('largeur sepal')
plt.colorbar()

# %%
from scipy import misc
face = misc.face(gray = True)
#plt.imshow(face, cmap = 'gray')
plt.hist(face.ravel(), bins = 255)
plt.show()

# %% [markdown]
# # (2) Contour plot

# %% [markdown]
# Pour resoudre le probleme d'optimisation

# %%
plt.contour(X, Y, Z, 20, colors = 'black')

# %%
plt.contourf(X, Y, Z, 20, cmap = 'RdGy')
plt.colorbar()

# %% [markdown]
# # (1) Imshow

# %% [markdown]
# Permet d'afficher les images

# %%
plt.imshow(face)

# %% [markdown]
#  Realisation d'une matrice de correlation

# %%
plt.imshow(np.corrcoef(x.T), cmap = 'Blues')
plt.colorbar()
plt.show()
